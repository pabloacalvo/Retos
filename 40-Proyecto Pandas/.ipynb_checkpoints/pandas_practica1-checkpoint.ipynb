# %%
import pandas as pd
import os
import openpyxl

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'practica1.ipynb',
#  'reviews.csv',
#  'reviews.ipynb',
#  'supermarkets',
#  'Untitled.ipynb']

# %%
df1 = pd.read_csv('./supermarkets/supermarkets.csv')
df1
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df2 = pd.read_json('./supermarkets/supermarkets.json')
df2
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df3 = pd.read_excel('./supermarkets/supermarkets.xlsx',sheet_name=0)
df3
# Out:
#    ID          Address           City             State Country  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA
# 1   2   735 Dolores St  San Francisco          CA 94119     USA
# 2   3      332 Hill St  San Francisco  California 94114     USA
# 3   4     3995 23rd St  San Francisco          CA 94114     USA
# 4   5  1056 Sanchez St  San Francisco        California     USA
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA
#
#   Supermarket Name  Number of Employees
# 0          Madeira                    8
# 1      Bready Shop                   15
# 2      Super River                   25
# 3       Ben's Shop                   10
# 4          Sanchez                   12
# 5       Richvalley                   20

# %%
df4 = pd.read_csv('./supermarkets/supermarkets.csv')
df4
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df5 = pd.read_csv('./supermarkets/supermarkets-semi-colons.txt', sep=';')
df5
# Out:
#    ID          Address           City             State Country          Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA       Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA   Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA   Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA    Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA       Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA    Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df6 = pd.read_csv('./supermarkets/supermarkets-without-headers.txt', sep=';', header=None)
df6
# Out:
#    0                1              2                 3    4             5   6
# 0  1     3666 21st St  San Francisco          CA 94114  USA       Madeira   8
# 1  2   735 Dolores St  San Francisco          CA 94119  USA   Bready Shop  15
# 2  3      332 Hill St  San Francisco  California 94114  USA   Super River  25
# 3  4     3995 23rd St  San Francisco          CA 94114  USA    Ben's Shop  10
# 4  5  1056 Sanchez St  San Francisco        California  USA       Sanchez  12
# 5  6  551 Alvarado St  San Francisco          CA 94114  USA    Richvalley  20

# %%
df6.columns = ['ID','Direccion','Ciudad','Estado','Pais','Nombre','Empleados']
df6
# Out:
#    ID        Direccion         Ciudad            Estado Pais        Nombre  \
# 0   1     3666 21st St  San Francisco          CA 94114  USA       Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119  USA   Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114  USA   Super River
# 3   4     3995 23rd St  San Francisco          CA 94114  USA    Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California  USA       Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114  USA    Richvalley
#
#    Empleados
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
# el cambio no es permanente
df6.set_index('ID')
# Out:
#           Direccion         Ciudad            Estado Pais        Nombre  \
# ID
# 1      3666 21st St  San Francisco          CA 94114  USA       Madeira
# 2    735 Dolores St  San Francisco          CA 94119  USA   Bready Shop
# 3       332 Hill St  San Francisco  California 94114  USA   Super River
# 4      3995 23rd St  San Francisco          CA 94114  USA    Ben's Shop
# 5   1056 Sanchez St  San Francisco        California  USA       Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114  USA    Richvalley
#
#     Empleados
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
df6
# Out:
#    ID        Direccion         Ciudad            Estado Pais        Nombre  \
# 0   1     3666 21st St  San Francisco          CA 94114  USA       Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119  USA   Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114  USA   Super River
# 3   4     3995 23rd St  San Francisco          CA 94114  USA    Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California  USA       Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114  USA    Richvalley
#
#    Empleados
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
# crea una nuevo dataframe
df7 = df6.set_index('ID')
df7
# Out:
#           Direccion         Ciudad            Estado Pais        Nombre  \
# ID
# 1      3666 21st St  San Francisco          CA 94114  USA       Madeira
# 2    735 Dolores St  San Francisco          CA 94119  USA   Bready Shop
# 3       332 Hill St  San Francisco  California 94114  USA   Super River
# 4      3995 23rd St  San Francisco          CA 94114  USA    Ben's Shop
# 5   1056 Sanchez St  San Francisco        California  USA       Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114  USA    Richvalley
#
#     Empleados
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
# para aplicar el cambio permanenente
df6.set_index('ID', inplace=True)
df6
# Out:
#           Direccion         Ciudad            Estado Pais        Nombre  \
# ID
# 1      3666 21st St  San Francisco          CA 94114  USA       Madeira
# 2    735 Dolores St  San Francisco          CA 94119  USA   Bready Shop
# 3       332 Hill St  San Francisco  California 94114  USA   Super River
# 4      3995 23rd St  San Francisco          CA 94114  USA    Ben's Shop
# 5   1056 Sanchez St  San Francisco        California  USA       Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114  USA    Richvalley
#
#     Empleados
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
df6.set_index("Direccion", inplace=True)
df6
# Out:
#                         Ciudad            Estado Pais        Nombre  Empleados
# Direccion
# 3666 21st St     San Francisco          CA 94114  USA       Madeira          8
# 735 Dolores St   San Francisco          CA 94119  USA   Bready Shop         15
# 332 Hill St      San Francisco  California 94114  USA   Super River         25
# 3995 23rd St     San Francisco          CA 94114  USA    Ben's Shop         10
# 1056 Sanchez St  San Francisco        California  USA       Sanchez         12
# 551 Alvarado St  San Francisco          CA 94114  USA    Richvalley         20

# %%
df6.set_index("Direccion", inplace=True)
df6
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_21164\3591285328.py in ?()
# ----> 1 df6.set_index("Direccion", inplace=True)
#       2 df6
#
# ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py in ?(self, keys, drop, append, inplace, verify_integrity)
#    6118                     if not found:
#    6119                         missing.append(col)
#    6120
#    6121         if missing:
# -> 6122             raise KeyError(f"None of {missing} are in the columns")
#    6123
#    6124         if inplace:
#    6125             frame = self
#
# KeyError: "None of ['Direccion'] are in the columns"

# %%
df5.loc["735 Dolores St":"332 Hill St"]
# Out:
# Empty DataFrame
# Columns: [ID, Address, City, State, Country, Name, Employees]
# Index: []

# %%
df5
# Out:
#    ID          Address           City             State Country          Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA       Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA   Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA   Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA    Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA       Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA    Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
# Capturar datos 
df5.iloc[1:4,1:4]
# Out:
#           Address           City             State
# 1  735 Dolores St  San Francisco          CA 94119
# 2     332 Hill St  San Francisco  California 94114
# 3    3995 23rd St  San Francisco          CA 94114

# %%
# Eliminacion de columna
df5.drop('City',axis=1)
# Out:
#    ID          Address             State Country          Name  Employees
# 0   1     3666 21st St          CA 94114     USA       Madeira          8
# 1   2   735 Dolores St          CA 94119     USA   Bready Shop         15
# 2   3      332 Hill St  California 94114     USA   Super River         25
# 3   4     3995 23rd St          CA 94114     USA    Ben's Shop         10
# 4   5  1056 Sanchez St        California     USA       Sanchez         12
# 5   6  551 Alvarado St          CA 94114     USA    Richvalley         20

# %%
# Eliminacion de fila
df5.drop(1,axis=0)
# Out:
#    ID          Address           City             State Country          Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA       Madeira
# 2   3      332 Hill St  San Francisco  California 94114     USA   Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA    Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA       Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA    Richvalley
#
#    Employees
# 0          8
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df6.index
# Out:
# Index(['3666 21st St', '735 Dolores St', '332 Hill St', '3995 23rd St',
#        '1056 Sanchez St', '551 Alvarado St'],
#       dtype='object', name='Direccion')

# %%
df6.columns
# Out:
# Index(['Ciudad', 'Estado', 'Pais', 'Nombre', 'Empleados'], dtype='object')

# %%
df6
# Out:
#                         Ciudad            Estado Pais        Nombre  Empleados
# Direccion
# 3666 21st St     San Francisco          CA 94114  USA       Madeira          8
# 735 Dolores St   San Francisco          CA 94119  USA   Bready Shop         15
# 332 Hill St      San Francisco  California 94114  USA   Super River         25
# 3995 23rd St     San Francisco          CA 94114  USA    Ben's Shop         10
# 1056 Sanchez St  San Francisco        California  USA       Sanchez         12
# 551 Alvarado St  San Francisco          CA 94114  USA    Richvalley         20

# %%
# Elimina filas basado en las coordenadas del indice
df6.drop(df6.index[0:3],axis=0)
# Out:
#                         Ciudad      Estado Pais      Nombre  Empleados
# Direccion
# 3995 23rd St     San Francisco    CA 94114  USA  Ben's Shop         10
# 1056 Sanchez St  San Francisco  California  USA     Sanchez         12
# 551 Alvarado St  San Francisco    CA 94114  USA  Richvalley         20

# %%
len(df1)
# Out:
# 6

# %%
df1['Continenent'] = df1.shape[0]*['North America']
df1
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees    Continenent
# 0          8  North America
# 1         15  North America
# 2         25  North America
# 3         10  North America
# 4         12  North America
# 5         20  North America

# %%
# Cantidad de filas y columnas
df1.shape
# Out:
# (6, 8)

# %%
df1["Continent"] = df1["Country"] + ',' + 'North America'
df1
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees    Continenent          Continent
# 0          8  North America  USA,North America
# 1         15  North America  USA,North America
# 2         25  North America  USA,North America
# 3         10  North America  USA,North America
# 4         12  North America  USA,North America
# 5         20  North America  USA,North America

# %%
# Elimino la columna con nombre erroneo con el parametro inplace se sobreescribe el df original
df1.drop('Continenent', axis=1,inplace=True)

# %%
# Creo una nueva columna tomando como parametro los datos de otra
df1["Continent"] = df1["Country"] + ',' + 'North America'
df1
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees          Continent
# 0          8  USA,North America
# 1         15  USA,North America
# 2         25  USA,North America
# 3         10  USA,North America
# 4         12  USA,North America
# 5         20  USA,North America

# %%
from geopy.geocoders import ArcGIS
nom = ArcGIS()

# %%
nom.geocode("3995 23rd St, San Francisco CA94114")
# Out:
# Location(3995 23rd St, San Francisco, California, 94114, (37.752926991206, -122.431710000351, 0.0))

# %%
import pandas
df = pandas.read_csv('./supermarkets/supermarkets.csv')
df
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df['Address'] = df['Address']+","+df["City"] + "," + df["State"] + "," + df["Country"]
df
# Out:
#    ID                                            Address           City  \
# 0   1  3666 21st St,San Francisco,CA 94114,USA,San Fr...  San Francisco
# 1   2  735 Dolores St,San Francisco,CA 94119,USA,San ...  San Francisco
# 2   3  332 Hill St,San Francisco,California 94114,USA...  San Francisco
# 3   4  3995 23rd St,San Francisco,CA 94114,USA,San Fr...  San Francisco
# 4   5  1056 Sanchez St,San Francisco,California,USA,S...  San Francisco
# 5   6  551 Alvarado St,San Francisco,CA 94114,USA,San...  San Francisco
#
#               State Country         Name  Employees
# 0          CA 94114     USA      Madeira          8
# 1          CA 94119     USA  Bready Shop         15
# 2  California 94114     USA  Super River         25
# 3          CA 94114     USA   Ben's Shop         10
# 4        California     USA      Sanchez         12
# 5          CA 94114     USA   Richvalley         20

# %%
df["Coordinates"] = df["Address"].apply(nom.geocode)

# %%
columna = df.iloc[:,7]
columna
# Out:
# 0    (3666 21st St, San Francisco, California, 9411...
# 1    (735 Dolores St, San Francisco, California, 94...
# 2    (332 Hill St, San Francisco, California, 94114...
# 3    (3995 23rd St, San Francisco, California, 9411...
# 4    (1056 Sanchez St, San Francisco, California, 9...
# 5    (551 Alvarado St, San Francisco, California, 9...
# Name: Coordinates, dtype: object

# %%
df['Latitude'] = df['Coordinates'].apply(lambda x: x.latitude if x != None else None)
df['Longitude'] = df['Coordinates'].apply(lambda x: x.longitude if x != None else None)
df
# Out:
#    ID                                            Address           City  \
# 0   1  3666 21st St,San Francisco,CA 94114,USA,San Fr...  San Francisco
# 1   2  735 Dolores St,San Francisco,CA 94119,USA,San ...  San Francisco
# 2   3  332 Hill St,San Francisco,California 94114,USA...  San Francisco
# 3   4  3995 23rd St,San Francisco,CA 94114,USA,San Fr...  San Francisco
# 4   5  1056 Sanchez St,San Francisco,California,USA,S...  San Francisco
# 5   6  551 Alvarado St,San Francisco,CA 94114,USA,San...  San Francisco
#
#               State Country         Name  Employees  \
# 0          CA 94114     USA      Madeira          8
# 1          CA 94119     USA  Bready Shop         15
# 2  California 94114     USA  Super River         25
# 3          CA 94114     USA   Ben's Shop         10
# 4        California     USA      Sanchez         12
# 5          CA 94114     USA   Richvalley         20
#
#                                          Coordinates   Latitude   Longitude
# ...

# %%
# Tipo de dato de una celda
type(df.at[0,"Coordinates"])
# Out:
# geopy.location.Location
